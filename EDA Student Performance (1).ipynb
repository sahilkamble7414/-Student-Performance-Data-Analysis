# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('student-por.csv')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.shape
# Out:
# (649, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
#univariate analysis

# %%
df['school'].value_counts(normalize=True)
# Out:
# school
# GP    0.651772
# MS    0.348228
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='school',data=df,palette= "muted")
plt.title('Dist of school')
# Out:
# Text(0.5, 1.0, 'Dist of school')

# %%
sns.histplot(x='age',data=df,bins=10,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#most of student are  in the age group 16-17 age

# %%
sns.countplot(x='address',data=df,palette='muted')
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %%
#there are mejority of student comes from urban rigion

# %%
df.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
df.reason.value_counts(normalize=True)
# Out:
# reason
# course        0.439137
# home          0.229584
# reputation    0.220339
# other         0.110940
# Name: proportion, dtype: float64

# %%
reason=df.reason.value_counts()

# %%
plt.pie(reason,labels=reason.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a994ccf0e0>,
# ...
#  [Text(0.2090477294642692, 1.0799532613987672, 'course'),
#   Text(-1.0374525300139155, -0.3656395054800917, 'home'),
#   Text(0.19858270739717565, -1.0819264800913266, 'reputation'),
#   Text(1.0338640880804848, -0.37566613818323835, 'other')],
#  [Text(0.11402603425323773, 0.5890654153084184, '43.9%'),
#   Text(-0.5658831981894084, -0.19943973026186818, '23.0%'),
#   Text(0.10831784039845943, -0.5901417164134508, '22.0%'),
#   Text(0.5639258662257188, -0.2049088026454027, '11.1%')])

# %%
df.activities.value_counts()
# Out:
# activities
# no     334
# yes    315
# Name: count, dtype: int64

# %%
ok=df.activities.value_counts()
plt.pie(ok,labels=ok.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a994d22ae0>,
# ...
#  [Text(-0.050567080655621474, 1.0988370990979364, 'no'),
#   Text(0.05056697777506705, -1.0988371038323632, 'yes')],
#  [Text(-0.027582043993975347, 0.5993656904170561, '51.5%'),
#   Text(0.027581987877309297, -0.5993656929994708, '48.5%')])

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.Walc.value_counts()
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
dalc=df.Dalc.value_counts()

# %%
plt.pie(dalc,labels=dalc.index,autopct='')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a994d85430>,
# ...
#  [Text(-0.6322660969560419, 0.9001330916258847, '1'),
#   Text(0.261059235896968, -1.068572915318787, '2'),
#   Text(0.9449951383804163, -0.5630134886815573, '3'),
#   Text(1.0666491428498037, -0.2688114693568322, '5'),
#   Text(1.0962775639680993, -0.09041848671687727, '4')],
#  [Text(-0.3448724165214774, 0.4909816863413916, ''),
#   Text(0.14239594685289161, -0.5828579538102474, ''),
#   Text(0.5154518936620452, -0.3070982665535767, ''),
#   Text(0.5818086233726202, -0.14662443783099938, ''),
#   Text(0.5979695803462359, -0.04931917457284215, '')])

# %%
#bivariate analysis

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.subplot(1 ,2, 1)
sns.countplot(x='Medu',data=df,palette='Set2')
plt.xlabel('mother education level')
plt.ylabel('count')
plt.title('mother education level dist')

plt.subplot(1,2,2)
sns.countplot(x='Fedu',data=df,palette='Set2')
plt.xlabel('fother education level')
plt.ylabel('count')
plt.title('father education level dist')
# Out:
# Text(0.5, 1.0, 'father education level dist')

# %%
#mother are more educated in term of higher educated as campared to father

# %%
sns.barplot(x='studytime',y='G3',data=df)
# Out:
# <Axes: xlabel='studytime', ylabel='G3'>

# %%
sns.barplot(x='studytime',y='G2',data=df)
# Out:
# <Axes: xlabel='studytime', ylabel='G2'>

# %%
sns.barplot(x='internet',y='G2',data=df)
# Out:
# <Axes: xlabel='internet', ylabel='G2'>

# %%
sns.barplot(x='sex',y='G3',hue='address',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='G3'>

# %%
num_cols=['age','traveltime','studytime','absences','G1','G2','G3']

# %%
sns.boxplot(data=df[num_cols])
# Out:
# <Axes: >

# %%
corr=df.corr(numeric_only=True)

# %%
plt.figure(figsize=(10,9))
sns.heatmap(corr,annot=True,fmt=".2f")
# Out:
# <Axes: >

# %%
#outlier detection

# %%
student_grade_df=df.copy()

# %%
student_grade_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
def detect_outliers(columns):
    outlier_indices=[]
    for column in columns:
        Q1=student_grade_df[column].quantile(0.25)
        Q3=student_grade_df[column].quantile(0.75)
        IQR=Q3-Q1
        
        #mask is a boolen candition
        mask= (student_grade_df[column]>=(Q1-1.5*IQR))& (student_grade_df[column]<=(Q3+1.5*IQR))
        mask=mask.to_numpy()# bool to numpy arrey
        #find the indices of values that do not satisfy the mask condition>> that will be outlier
        false_indices = np.argwhere(~mask)
        outlier_indices.append(false_indices)
        return np.unique(np.concatenate(outlier_indices).ravel())

# %%
def detect_outliers(columns):
    outlier_indices = []
    for column in columns:
        Q1=student_grade_df[column].quantile(0.25)
        Q3=student_grade_df[column].quantile(0.75)
        IQR = Q3-Q1
        
        #mask is a boolean condition
        mask = (student_grade_df[column] >= (Q1-1.5*IQR)) & (student_grade_df[column] <= (Q3+1.5*IQR))
        mask = mask.to_numpy() #bool to numpy array
        
        #find the indices of values that do not satisfy the mask condition>> that will be outlier
        false_indices = np.argwhere(~mask)
        outlier_indices.append(false_indices)
    return np.unique(np.concatenate(outlier_indices).ravel())

# %%
#np.concatenate(outlier_indices)>> combine all the outlier index arrays into a single array
#so each column will have one array
#.ravel>> flattens the multi-dimensional array into 1 d array

# %%
num_cols = ["age", "absences"]
detect_outliers(num_cols)
# Out:
# array([ 40, 103, 150, 155, 161, 197, 206, 211, 212, 217, 230, 253, 254,
#        256, 263, 279, 311, 325, 326, 397, 405, 413], dtype=int64)

# %%
student_grade_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
x,y=student_grade_df.iloc[:,:-1],student_grade_df.iloc[:,-1]

# %%
x
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
y
# Out:
# 0      11
# 1      11
# 2      12
# 3      14
# 4      13
#        ..
# 644    10
# 645    16
# 646     9
# 647    10
# 648    11
# Name: G3, Length: 649, dtype: int64

# %%
student_grade_df.drop('health',axis=1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
student_grade_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
x_train.shape
# Out:
# (486, 32)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.sex.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.sex.unique()
# Out:
# array([nan])

# %%
df.dtypes
# Out:
# school         object
# sex           float64
# age             int64
# address        object
# famsize        object
# Pstatus        object
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet       object
# romantic       object
# famrel          int64
# freetime        int64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# G1              int64
# G2              int64
# G3              int64
# dtype: object

# %%
df.describe()
# Out:
#        sex         age        Medu        Fedu  traveltime   studytime  \
# count  0.0  649.000000  649.000000  649.000000  649.000000  649.000000
# mean   NaN   16.744222    2.514638    2.306626    1.568567    1.930663
# std    NaN    1.218138    1.134552    1.099931    0.748660    0.829510
# min    NaN   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%    NaN   16.000000    2.000000    1.000000    1.000000    1.000000
# 50%    NaN   17.000000    2.000000    2.000000    1.000000    2.000000
# 75%    NaN   18.000000    4.000000    3.000000    2.000000    2.000000
# max    NaN   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     0.221880    3.930663    3.180277    3.184900    1.502311    2.280431
# std      0.593235    0.955717    1.051093    1.175766    0.924834    1.284380
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         0 non-null      float64
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
for col in df.columns:
    print(f"{col}: {df[col].unique()}\n")
# Out:
# school: ['GP' 'MS']
#
# sex: [nan]
#
# age: [18 17 15 16 19 22 20 21]
#
# address: ['U' 'R']
#
# famsize: ['GT3' 'LE3']
#
# Pstatus: ['A' 'T']
#
# Medu: [4 1 3 2 0]
#
# Fedu: [4 1 2 3 0]
#
# Mjob: ['at_home' 'health' 'other' 'services' 'teacher']
#
# Fjob: ['teacher' 'other' 'services' 'health' 'at_home']
#
# reason: ['course' 'other' 'home' 'reputation']
#
# guardian: ['mother' 'father' 'other']
#
# traveltime: [2 1 3 4]
#
# studytime: [2 3 1 4]
#
# failures: [0 3 1 2]
#
# schoolsup: ['yes' 'no']
#
# famsup: ['no' 'yes']
#
# paid: ['no' 'yes']
#
# activities: ['no' 'yes']
#
# nursery: ['yes' 'no']
#
# higher: ['yes' 'no']
#
# internet: ['no' 'yes']
#
# romantic: ['no' 'yes']
#
# famrel: [4 5 3 1 2]
#
# freetime: [3 2 4 1 5]
#
# goout: [4 3 2 1 5]
#
# Dalc: [1 2 5 3 4]
#
# Walc: [1 3 2 4 5]
#
# health: [3 5 1 2 4]
#
# absences: [ 4  2  6  0 10  8 16 14  1 12 24 22 32 30 21 15  9 18 26  7 11  5 13  3]
#
# G1: [ 0  9 12 14 11 13 10 15 17  8 16 18  7  6  5  4 19]
#
# ...

# %%
df['romantic'].dtypes
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# school         object
# sex           float64
# age             int64
# address        object
# famsize        object
# Pstatus        object
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet       object
# romantic      float64
# famrel          int64
# freetime        int64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# G1              int64
# G2              int64
# G3              int64
# dtype: object

# %%
df.romantic.unique
# Out:
# <bound method Series.unique of 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 644   NaN
# 645   NaN
# 646   NaN
# 647   NaN
# 648   NaN
# Name: romantic, Length: 649, dtype: float64>

# %%
df['romantic'] = df['romantic'].map({'no': 0, 'yes': 1})

# %%
df.romantic.unique
# Out:
# <bound method Series.unique of 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 644   NaN
# 645   NaN
# 646   NaN
# 647   NaN
# 648   NaN
# Name: romantic, Length: 649, dtype: float64>

# %%
df['internet'] = df['internet'].map({'no': 0, 'yes': 1})

# %%
df['internet'].dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# school         object
# sex           float64
# age             int64
# address        object
# famsize        object
# Pstatus        object
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet        int64
# romantic      float64
# famrel          int64
# freetime        int64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# G1              int64
# G2              int64
# G3              int64
# dtype: object

# %%
df.drop('address',axis=1)
# Out:
#     school  sex  age famsize Pstatus  Medu  Fedu      Mjob      Fjob  reason  \
# 0       GP  NaN   18     GT3       A     4     4   at_home   teacher  course
# 1       GP  NaN   17     GT3       T     1     1   at_home     other  course
# 2       GP  NaN   15     LE3       T     1     1   at_home     other   other
# 3       GP  NaN   15     GT3       T     4     2    health  services    home
# 4       GP  NaN   16     GT3       T     3     3     other     other    home
# ..     ...  ...  ...     ...     ...   ...   ...       ...       ...     ...
# 644     MS  NaN   19     GT3       T     2     3  services     other  course
# 645     MS  NaN   18     LE3       T     3     1   teacher  services  course
# 646     MS  NaN   18     GT3       T     1     1     other     other  course
# 647     MS  NaN   17     LE3       T     3     1  services  services  course
# 648     MS  NaN   18     LE3       T     3     2  services     other  course
#
# ...

# %%
df
# Out:
#     school  sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP  NaN   18       U     GT3       A     4     4   at_home   teacher
# 1       GP  NaN   17       U     GT3       T     1     1   at_home     other
# 2       GP  NaN   15       U     LE3       T     1     1   at_home     other
# 3       GP  NaN   15       U     GT3       T     4     2    health  services
# 4       GP  NaN   16       U     GT3       T     3     3     other     other
# ..     ...  ...  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS  NaN   19       R     GT3       T     2     3  services     other
# 645     MS  NaN   18       U     LE3       T     3     1   teacher  services
# 646     MS  NaN   18       U     GT3       T     1     1     other     other
# 647     MS  NaN   17       U     LE3       T     3     1  services  services
# 648     MS  NaN   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.dtypes
# Out:
# school         object
# sex           float64
# age             int64
# address        object
# famsize        object
# Pstatus        object
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet        int64
# romantic      float64
# famrel          int64
# freetime        int64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# G1              int64
# G2              int64
# G3              int64
# dtype: object

# %%
sns.barplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex'>

# %%
df.drop('sex', axis=1, inplace=True)

# %%
df.drop('romantic', axis=1, inplace=True)

# %%
df
# Out:
#     school  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   17       U     GT3       T     1     1   at_home     other
# 2       GP   15       U     LE3       T     1     1   at_home     other
# 3       GP   15       U     GT3       T     4     2    health  services
# 4       GP   16       U     GT3       T     3     3     other     other
# ..     ...  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   19       R     GT3       T     2     3  services     other
# 645     MS   18       U     LE3       T     3     1   teacher  services
# 646     MS   18       U     GT3       T     1     1     other     other
# 647     MS   17       U     LE3       T     3     1  services  services
# 648     MS   18       R     LE3       T     3     2  services     other
#
#      reason  ... famrel  freetime  goout  Dalc Walc health absences  G1  G2  \
# ...

# %%
df.dtypes
# Out:
# school        object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet       int64
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df['higher']=df['higher'].map({'yes':1,'no':0})#df['romantic'] = df['romantic'].map({'no': 0, 'yes': 1})

# %%
df.higher.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['paid'] = df['paid'].map({'no': 0, 'yes': 1})
df['nursery'] = df['nursery'].map({'no': 0, 'yes': 1})
df['activities'] = df['activities'].map({'no': 0, 'yes': 1})
df['schoolsup'] = df['schoolsup'].map({'no': 0, 'yes': 1})
df['famsup'] = df['famsup'].map({'no': 0, 'yes': 1})

# %%
df.dtypes
# Out:
# school        object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup      int64
# famsup         int64
# paid           int64
# activities     int64
# nursery        int64
# higher         int64
# internet       int64
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
cols_to_map = ['paid', 'nursery', 'activities', 'schoolsup', 'famsup']

for col in cols_to_map:
    df[col] = df[col].map({'no': 0, 'yes': 1})
